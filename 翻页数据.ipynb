'/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E6%96%B0%E5%AA%92%E4%BD%93%E8%BF%90%E8%90%A5&siTag=qkuPMtyyPWyGJLVm3Ykn1A%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=fad59132059273d320c20f3d6f365011&d_curPage=0&d_pageSize=40&d_headId=fad59132059273d320c20f3d6f365011&curPage=9'}

# %%
# 建构参数模板：找到关键参数及参数结构
from urllib.parse import urlparse, parse_qs
import pandas as pd
from IPython.display import display, HTML

# 总体目标：输入 href_列表, 建构出参数字典

# urlparse 解析后丢入数据框
df = pd.DataFrame([ urlparse(x) for x in href_列表])
df_qs = pd.DataFrame([{k:v[0] for k,v in parse_qs(x).items()} for x in df['query'] ])

display(df)
print(df.nunique())
display(df_qs)
print(df_qs.nunique())

df_qs.curPage
df_qs = df_qs.assign (curPage_int=df_qs.curPage.astype(int))
# Out:
#   scheme netloc       path params  \
# 0                /zhaopin/
# 1                /zhaopin/
# 2                /zhaopin/
# 3                /zhaopin/
# 4                /zhaopin/
# 5                /zhaopin/
#
#                                                query fragment
# 0  compkind=&dqs=&pubTime=&pageSize=40&salary=&co...
# 1  compkind=&dqs=&pubTime=&pageSize=40&salary=&co...
# 2  compkind=&dqs=&pubTime=&pageSize=40&salary=&co...
# 3  compkind=&dqs=&pubTime=&pageSize=40&salary=&co...
# 4  compkind=&dqs=&pubTime=&pageSize=40&salary=&co...
# 5  compkind=&dqs=&pubTime=&pageSize=40&salary=&co...
# scheme      1
# netloc      1
# path        1
# params      1
# query       5
# fragment    1
# dtype: int64
#   curPage                            d_ckId d_curPage  \
# 0       1  fad59132059273d320c20f3d6f365011         0
# 1       2  fad59132059273d320c20f3d6f365011         0
# 2       3  fad59132059273d320c20f3d6f365011         0
# 3       4  fad59132059273d320c20f3d6f365011         0
# 4       1  fad59132059273d320c20f3d6f365011         0
# 5       9  fad59132059273d320c20f3d6f365011         0
#
#                            d_headId d_pageSize         d_sfrom    key  \
# 0  fad59132059273d320c20f3d6f365011         40  search_unknown  新媒体运营
# 1  fad59132059273d320c20f3d6f365011         40  search_unknown  新媒体运营
# 2  fad59132059273d320c20f3d6f365011         40  search_unknown  新媒体运营
# 3  fad59132059273d320c20f3d6f365011         40  search_unknown  新媒体运营
# 4  fad59132059273d320c20f3d6f365011         40  search_unknown  新媒体运营
# 5  fad59132059273d320c20f3d6f365011         40  search_unknown  新媒体运营
#
#   pageSize                                          siTag     sortFlag
# 0       40  qkuPMtyyPWyGJLVm3Ykn1A~fA9rXquZc5IkJpXC-Ycixw  °radeFlag=0
# 1       40  qkuPMtyyPWyGJLVm3Ykn1A~fA9rXquZc5IkJpXC-Ycixw  °radeFlag=0
# 2       40  qkuPMtyyPWyGJLVm3Ykn1A~fA9rXquZc5IkJpXC-Ycixw  °radeFlag=0
# 3       40  qkuPMtyyPWyGJLVm3Ykn1A~fA9rXquZc5IkJpXC-Ycixw  °radeFlag=0
# 4       40  qkuPMtyyPWyGJLVm3Ykn1A~fA9rXquZc5IkJpXC-Ycixw  °radeFlag=0
# 5       40  qkuPMtyyPWyGJLVm3Ykn1A~fA9rXquZc5IkJpXC-Ycixw  °radeFlag=0
# curPage       5
# d_ckId        1
# d_curPage     1
# d_headId      1
# d_pageSize    1
# d_sfrom       1
# key           1
# pageSize      1
# siTag         1
# sortFlag      1
# dtype: int64

# %%
# 建构参数模板：找到关键参数及参数结构

def parse_url_qs_for_curPage (url):
    six_parts = urlparse(url) 
    out = parse_qs(six_parts.query)
    return (out)

# 取一例做模板
参数模板 = parse_url_qs_for_curPage(href_列表[0])
print (参数模板)

print (href_字典)
# Out:
# {'pageSize': ['40'], 'sortFlag': ['°radeFlag=0'], 'key': ['新媒体运营'], 'siTag': ['qkuPMtyyPWyGJLVm3Ykn1A~fA9rXquZc5IkJpXC-Ycixw'], 'd_sfrom': ['search_unknown'], 'd_ckId': ['fad59132059273d320c20f3d6f365011'], 'd_curPage': ['0'], 'd_pageSize': ['40'], 'd_headId': ['fad59132059273d320c20f3d6f365011'], 'curPage': ['1']}
# {'2': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E6%96%B0%E5%AA%92%E4%BD%93%E8%BF%90%E8%90%A5&siTag=qkuPMtyyPWyGJLVm3Ykn1A%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=fad59132059273d320c20f3d6f365011&d_curPage=0&d_pageSize=40&d_headId=fad59132059273d320c20f3d6f365011&curPage=1', '3': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E6%96%B0%E5%AA%92%E4%BD%93%E8%BF%90%E8%90%A5&siTag=qkuPMtyyPWyGJLVm3Ykn1A%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=fad59132059273d320c20f3d6f365011&d_curPage=0&d_pageSize=40&d_headId=fad59132059273d320c20f3d6f365011&curPage=2', '4': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E6%96%B0%E5%AA%92%E4%BD%93%E8%BF%90%E8%90%A5&siTag=qkuPMtyyPWyGJLVm3Ykn1A%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=fad59132059273d320c20f3d6f365011&d_curPage=0&d_pageSize=40&d_headId=fad59132059273d320c20f3d6f365011&curPage=3', '5': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E6%96%B0%E5%AA%92%E4%BD%93%E8%BF%90%E8%90%A5&siTag=qkuPMtyyPWyGJLVm3Ykn1A%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=fad59132059273d320c20f3d6f365011&d_curPage=0&d_pageSize=40&d_headId=fad59132059273d320c20f3d6f365011&curPage=4', '下一页': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E6%96%B0%E5%AA%92%E4%BD%93%E8%BF%90%E8%90%A5&siTag=qkuPMtyyPWyGJLVm3Ykn1A%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=fad59132059273d320c20f3d6f365011&d_curPage=0&d_pageSize=40&d_headId=fad59132059273d320c20f3d6f365011&curPage=1', '': '/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=&sortFlag=°radeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E6%96%B0%E5%AA%92%E4%BD%93%E8%BF%90%E8%90%A5&siTag=qkuPMtyyPWyGJLVm3Ykn1A%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=fad59132059273d320c20f3d6f365011&d_curPage=0&d_pageSize=40&d_headId=fad59132059273d320c20f3d6f365011&curPage=9'}

# %%
# 建构参数模板生成器：keyword curPage
def 参数模板生成(keyword, curPage):
    参数 = 参数模板.copy()
    参数['curPage'] = curPage
    参数['keyword'] = keyword
    return (参数)

参数_keyword_新媒体运营_curPage = { 
    i:参数模板生成(curPage = [i], \
                  keyword = ['新媒体运营']) \
    for i,v in href_字典.items()\
    }

# print(参数_keyword_用户体验_curPage) # 只生成本页有的额外翻页URL, 并没有推估到&curPage=9,也没有这页

print (df_qs.curPage_int.min()) # 最小值只有1
print (df_qs.curPage_int.max()) # 最大值只有9

# 应该是 0 (本页)....9(最大值)

参数_keyword_新媒体运营_curPage = { 
    i:参数模板生成(curPage = [i], \
                  keyword = ['新媒体运营']) \
    for i in range(0,df_qs.curPage_int.max()+1)\
    }
参数_keyword_新媒体运营_curPage
# Out:
# 1
# 9
# {0: {'curPage': [0],
#   'd_ckId': ['fad59132059273d320c20f3d6f365011'],
#   'd_curPage': ['0'],
#   'd_headId': ['fad59132059273d320c20f3d6f365011'],
#   'd_pageSize': ['40'],
#   'd_sfrom': ['search_unknown'],
#   'key': ['新媒体运营'],
#   'keyword': ['新媒体运营'],
#   'pageSize': ['40'],
#   'siTag': ['qkuPMtyyPWyGJLVm3Ykn1A~fA9rXquZc5IkJpXC-Ycixw'],
#   'sortFlag': ['°radeFlag=0']},
#  1: {'curPage': [1],
#   'd_ckId': ['fad59132059273d320c20f3d6f365011'],
#   'd_curPage': ['0'],
#   'd_headId': ['fad59132059273d320c20f3d6f365011'],
#   'd_pageSize': ['40'],
#   'd_sfrom': ['search_unknown'],
#   'key': ['新媒体运营'],
#   'keyword': ['新媒体运营'],
#   'pageSize': ['40'],
#   'siTag': ['qkuPMtyyPWyGJLVm3Ykn1A~fA9rXquZc5IkJpXC-Ycixw'],
#   'sortFlag': ['°radeFlag=0']},
#  2: {'curPage': [2],
#   'd_ckId': ['fad59132059273d320c20f3d6f365011'],
#   'd_curPage': ['0'],
#   'd_headId': ['fad59132059273d320c20f3d6f365011'],
#   'd_pageSize': ['40'],
#   'd_sfrom': ['search_unknown'],
#   'key': ['新媒体运营'],
#   'keyword': ['新媒体运营'],
#   'pageSize': ['40'],
#   'siTag': ['qkuPMtyyPWyGJLVm3Ykn1A~fA9rXquZc5IkJpXC-Ycixw'],
#   'sortFlag': ['°radeFlag=0']},
#  3: {'curPage': [3],
#   'd_ckId': ['fad59132059273d320c20f3d6f365011'],
#   'd_curPage': ['0'],
#   'd_headId': ['fad59132059273d320c20f3d6f365011'],
#   'd_pageSize': ['40'],
#   'd_sfrom': ['search_unknown'],
#   'key': ['新媒体运营'],
#   'keyword': ['新媒体运营'],
#   'pageSize': ['40'],
#   'siTag': ['qkuPMtyyPWyGJLVm3Ykn1A~fA9rXquZc5IkJpXC-Ycixw'],
#   'sortFlag': ['°radeFlag=0']},
#  4: {'curPage': [4],
#   'd_ckId': ['fad59132059273d320c20f3d6f365011'],
#   'd_curPage': ['0'],
#   'd_headId': ['fad59132059273d320c20f3d6f365011'],
#   'd_pageSize': ['40'],
#   'd_sfrom': ['search_unknown'],
#   'key': ['新媒体运营'],
#   'keyword': ['新媒体运营'],
#   'pageSize': ['40'],
#   'siTag': ['qkuPMtyyPWyGJLVm3Ykn1A~fA9rXquZc5IkJpXC-Ycixw'],
#   'sortFlag': ['°radeFlag=0']},
#  5: {'curPage': [5],
#   'd_ckId': ['fad59132059273d320c20f3d6f365011'],
#   'd_curPage': ['0'],
#   'd_headId': ['fad59132059273d320c20f3d6f365011'],
#   'd_pageSize': ['40'],
#   'd_sfrom': ['search_unknown'],
#   'key': ['新媒体运营'],
#   'keyword': ['新媒体运营'],
#   'pageSize': ['40'],
#   'siTag': ['qkuPMtyyPWyGJLVm3Ykn1A~fA9rXquZc5IkJpXC-Ycixw'],
#   'sortFlag': ['°radeFlag=0']},
#  6: {'curPage': [6],
#   'd_ckId': ['fad59132059273d320c20f3d6f365011'],
#   'd_curPage': ['0'],
#   'd_headId': ['fad59132059273d320c20f3d6f365011'],
#   'd_pageSize': ['40'],
#   'd_sfrom': ['search_unknown'],
#   'key': ['新媒体运营'],
#   'keyword': ['新媒体运营'],
#   'pageSize': ['40'],
#   'siTag': ['qkuPMtyyPWyGJLVm3Ykn1A~fA9rXquZc5IkJpXC-Ycixw'],
#   'sortFlag': ['°radeFlag=0']},
#  7: {'curPage': [7],
#   'd_ckId': ['fad59132059273d320c20f3d6f365011'],
#   'd_curPage': ['0'],
#   'd_headId': ['fad59132059273d320c20f3d6f365011'],
#   'd_pageSize': ['40'],
#   'd_sfrom': ['search_unknown'],
#   'key': ['新媒体运营'],
#   'keyword': ['新媒体运营'],
#   'pageSize': ['40'],
#   'siTag': ['qkuPMtyyPWyGJLVm3Ykn1A~fA9rXquZc5IkJpXC-Ycixw'],
#   'sortFlag': ['°radeFlag=0']},
#  8: {'curPage': [8],
#   'd_ckId': ['fad59132059273d320c20f3d6f365011'],
#   'd_curPage': ['0'],
#   'd_headId': ['fad59132059273d320c20f3d6f365011'],
#   'd_pageSize': ['40'],
#   'd_sfrom': ['search_unknown'],
#   'key': ['新媒体运营'],
#   'keyword': ['新媒体运营'],
#   'pageSize': ['40'],
#   'siTag': ['qkuPMtyyPWyGJLVm3Ykn1A~fA9rXquZc5IkJpXC-Ycixw'],
#   'sortFlag': ['°radeFlag=0']},
#  9: {'curPage': [9],
#   'd_ckId': ['fad59132059273d320c20f3d6f365011'],
#   'd_curPage': ['0'],
#   'd_headId': ['fad59132059273d320c20f3d6f365011'],
#   'd_pageSize': ['40'],
#   'd_sfrom': ['search_unknown'],
#   'key': ['新媒体运营'],
#   'keyword': ['新媒体运营'],
#   'pageSize': ['40'],
#   'siTag': ['qkuPMtyyPWyGJLVm3Ykn1A~fA9rXquZc5IkJpXC-Ycixw'],
#   'sortFlag': ['°radeFlag=0']}}

# %%
# requests_liepin
session = HTMLSession()

def requests_liepin( url, params):
    r = session.get( url , params = payload)

    # 先取特定元素, 精准打击其子后辈
    主要元素 = r.html.xpath( '//ul[@class="sojob-list"]/li')

    # 作为xpath字典，键为我要抓的牛肉名称，值为xpath
    dict_xpaths={ 
        'text': {
            'edu':      '//div[contains(@class,"job-info")]/p/span[@class="edu"]',
            '经验':      '//div[contains(@class,"job-info")]/p/span[@class="edu"]/following-sibling::span',
            '薪水':    '//div[contains(@class,"job-info")]/p/span[@class="text-warning"]', 
            '时间':    '//div[contains(@class,"job-info")]/p/time/@title', 
            '职称':    '//div[contains(@class,"job-info")]/h3/a', 
            '公司地点': '//div[contains(@class,"job-info")]/p/a',
            '公司名称': '//div[contains(@class,"sojob-item-main")]//p[@class="company-name"]/a', 
        },
        'text_content': {
        },
        'href': {
            '链结':    '//div[contains(@class,"job-info")]/h3/a', 
            '公司URL': '//div[contains(@class,"sojob-item-main")]//p[@class="company-name"]/a', 
        }
    }

    def get_e_text_content(_xpath_):
        # 高级列表推导
        暂存结果 = [e.xpath(_xpath_)[0].lxml.text_content() for e in 主要元素]
        return(暂存结果)

    def get_e_text(_xpath_):
        # 高级列表推导
        暂存结果 = ["".join([x.strip() if type(x) is str else x.text.strip() for x in e.xpath(_xpath_)]) for e in 主要元素]
        return(暂存结果)

    def get_e_href(_xpath_):
        # 高级列表推导
        暂存结果 = [list(e.xpath(_xpath_, first=True).absolute_links)[0] \
                   if len(e.xpath(_xpath_, first=True).absolute_links) >= 1  \
                   else "" for e in 主要元素]
        return(暂存结果)

    # 只对主要元素下进行.xpath取值
    数据字典 = dict()

    数据字典 = {k:get_e_text_content(v) for k,v in dict_xpaths['text_content'].items()}
    数据字典.update({k:get_e_text(v) for k,v in dict_xpaths['text'].items()})
    数据字典.update({k:get_e_href(v) for k,v in dict_xpaths['href'].items()})

    数据 = pd.DataFrame(数据字典)
    #数据.to_excel("20春_Web数据挖掘_week03_liepin.xlsx", sheet_name="搜查结果")
    return (数据)

# %%
# %%time

import time
from random import random

url = "https://www.liepin.com/zhaopin/"

list_df = list()
for k,v in 参数_keyword_新媒体运营_curPage.items():
    payload = v
    df = requests_liepin( url, params = payload)
    time.sleep(3+4*random())  #放慢脚步 3-7秒, 平均约5秒
    df = df.assign (curPage = k)  # 区分  curPage
    list_df.append(df)

df_all = pd.concat(list_df).reset_index()
df_all.index.name = '序'

# 上周C-4   输出
df_all.to_excel("20春_Web数据挖掘_final_新媒体运营_翻页.xlsx",\
                sheet_name="新媒体运营")
# Out:
# Wall time: 1min 11s

# %%
# %%time
# B-3 多个页面+多个关键词
import time
from random import random

url = "https://www.liepin.com/zhaopin/"
xpath_翻页a = '//div[@class="pagerbar"]/a[starts-with(@href,"/zhaopin")]'

keywords = ['新媒体运营','产品经理']
list_df = list()

## 第一页试探有多长的页面
for key in keywords:
    payload = 参数模板生成(keyword=[key], curPage=['0'])
    df = requests_liepin( url, params = payload)
    href_列表 = [x.xpath('//@href')[0] for x in r.html.xpath(xpath_翻页a)]
    df = pd.DataFrame([ urlparse(x) for x in href_列表])
    df_qs = pd.DataFrame([{k:v[0] for k,v in parse_qs(x).items()} for x in df['query'] ])
    df_qs = df_qs.assign (curPage_int=df_qs.curPage.astype(int)) # 变成整数
    长度 = df_qs.curPage_int.max()+1
    参数_keyword_X_curPage = { 
        i:参数模板生成(curPage = [i], \
                      keyword = [key]) \
        for i in range(0,长度)\
        }
    #print (参数_keyword_X_curPage)
    print (key,长度)
    
    for k,v in 参数_keyword_X_curPage.items():
        payload = v
        df = requests_liepin( url, params = payload)
        time.sleep(3+4*random())  #放慢脚步 3-7秒, 平均约5秒
        df = df.assign (keyword = key)  # 区分  keyword    
        df = df.assign (curPage = k)  # 区分  curPage    
        list_df.append(df)
        
df_all = pd.concat(list_df).reset_index()
df_all.index.name = '序'

df_all.to_excel("双关键词_Web数据挖掘_final_liepin_翻页.xlsx",\
                sheet_name="_".join(keywords))
# Out:
# 新媒体运营 10
# 产品经理 10
# Wall time: 2min 10s
